# %% [markdown]
# <a href="https://colab.research.google.com/github/ms-starryvoid/ML_Lab_DataSet/blob/main/Programs/DocumentClassificationUsingNaiveBayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix
from sklearn.feature_extraction.text import CountVectorizer

df= pd.read_csv('https://github.com/ms-starryvoid/ML_Lab_DataSet/raw/refs/heads/main/Lab_data/spam.csv',encoding='latin-1')
df = df[['v1', 'v2']]

# Rename columns for clarity
df.columns = ['label', 'message']

# Convert labels to numerical (0 for ham, 1 for spam)
df['label'] = df['label'].map({'ham': 0, 'spam': 1})

print('\nSample Data Set\n',df.head())
print("\ncolumns\n",df.columns)
# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['message'], df['label'], test_size=0.2)

# Vectorize the text data
vectorizer = CountVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# Train a Naive Bayes classifier
model = MultinomialNB()
model.fit(X_train_vec, y_train)

# Make predictions
y_pred = model.predict(X_test_vec)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

print("\nAccuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("Confusion Matrix:\n", conf_matrix)
# Out:
# Sample Data Set
#     label                                            message
# 0      0  Go until jurong point, crazy.. Available only ...
# 1      0                      Ok lar... Joking wif u oni...
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      0  U dun say so early hor... U c already then say...
# 4      0  Nah I don't think he goes to usf, he lives aro...
#
# columns
#  Index(['label', 'message'], dtype='object')
#
# Accuracy: 0.989237668161435
# Precision: 0.9867549668874173
# Recall: 0.9371069182389937
# Confusion Matrix:
#  [[954   2]
#  [ 10 149]]
